# %% [markdown]
# <a href="https://colab.research.google.com/github/Pragalbhv/atomai/blob/master/examples/notebooks/Instance_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy==1.26.4
# Out:
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy==1.26.4) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy==1.26.4) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy==1.26.4) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy==1.26.4) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy==1.26.4) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy==1.26.4) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Instance Segmentation Demo 2: Additive Manufacturing dataset
#
# This is a short demo of the instance segmentation utility of the improved AtomAI model. The instance segmentation works using watershed segmentation, connected components and rules based on geometry.
#
#
# The data contains optical micrographs of H13 and Inconel 625 steels along with manually marked image-maps.

# %%
# !pip install git+https://github.com/Pragalbhv/atomai # install the latest version from sourcefrom sklearn.metrics import classification_report
# Out:
# Collecting git+https://github.com/Pragalbhv/atomai
#   Cloning https://github.com/Pragalbhv/atomai to /tmp/pip-req-build-u0qw95oe
#   Running command git clone --filter=blob:none --quiet https://github.com/Pragalbhv/atomai /tmp/pip-req-build-u0qw95oe
#   Resolved https://github.com/Pragalbhv/atomai to commit 332eb384645c5a46eda9f6068661ad212737e6e0
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (1.26.4)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (3.7.2)
# Requirement already satisfied: scipy>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.22.1 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (1.2.2)
# Requirement already satisfied: scikit-image>=0.16.2 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (0.25.2)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (4.11.0.86)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (3.4.2)
# Collecting mendeleev<=0.6.1 (from atomai==0.7.8.1.1)
#   Downloading mendeleev-0.6.1.tar.gz (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (0.21.0+cu124)
# Requirement already satisfied: progressbar2>=3.38.0 in /usr/local/lib/python3.11/dist-packages (from atomai==0.7.8.1.1) (4.5.0)
# Collecting gpytorch>=1.9.1 (from atomai==0.7.8.1.1)
#   Downloading gpytorch-1.14-py3-none-any.whl.metadata (8.0 kB)
# Collecting jaxtyping (from gpytorch>=1.9.1->atomai==0.7.8.1.1)
#   Downloading jaxtyping-0.3.2-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.11/dist-packages (from gpytorch>=1.9.1->atomai==0.7.8.1.1) (1.3.0)
# Collecting linear-operator>=0.6 (from gpytorch>=1.9.1->atomai==0.7.8.1.1)
#   Downloading linear_operator-0.6-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (11.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4->atomai==0.7.8.1.1) (2.9.0.post0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from mendeleev<=0.6.1->atomai==0.7.8.1.1) (2.2.3)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from mendeleev<=0.6.1->atomai==0.7.8.1.1) (2.0.40)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from mendeleev<=0.6.1->atomai==0.7.8.1.1) (0.4.6)
# Collecting pyfiglet (from mendeleev<=0.6.1->atomai==0.7.8.1.1)
#   Downloading pyfiglet-1.0.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->atomai==0.7.8.1.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->atomai==0.7.8.1.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->atomai==0.7.8.1.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->atomai==0.7.8.1.1) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->atomai==0.7.8.1.1) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->atomai==0.7.8.1.1) (2.4.1)
# Requirement already satisfied: python-utils>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from progressbar2>=3.38.0->atomai==0.7.8.1.1) (3.9.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.16.2->atomai==0.7.8.1.1) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.16.2->atomai==0.7.8.1.1) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.16.2->atomai==0.7.8.1.1) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.1->atomai==0.7.8.1.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22.1->atomai==0.7.8.1.1) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (4.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.0.0->atomai==0.7.8.1.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->atomai==0.7.8.1.1) (1.13.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->atomai==0.7.8.1.1) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.3.0->mendeleev<=0.6.1->atomai==0.7.8.1.1) (3.1.1)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping->gpytorch>=1.9.1->atomai==0.7.8.1.1)
#   Downloading wadler_lindig-0.1.6-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.0.0->atomai==0.7.8.1.1) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->atomai==0.7.8.1.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->atomai==0.7.8.1.1) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.5->atomai==0.7.8.1.1) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.5->atomai==0.7.8.1.1) (2024.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->mendeleev<=0.6.1->atomai==0.7.8.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->mendeleev<=0.6.1->atomai==0.7.8.1.1) (2025.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.5->atomai==0.7.8.1.1) (2024.2.0)
# Downloading gpytorch-1.14-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01m
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.5 MB/s eta 0:00:0000:0100:01
# Downloading linear_operator-0.6-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.3/176.3 kB 12.0 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 3.6 MB/s eta 0:00:00
# Downloading pyfiglet-1.0.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.1 MB/s eta 0:00:0000:01
# Downloading wadler_lindig-0.1.6-py3-none-any.whl (20 kB)
# Building wheels for collected packages: atomai, mendeleev
#   Building wheel for atomai (setup.py) ... done
#   Created wheel for atomai: filename=atomai-0.7.8.1.1-py3-none-any.whl size=183439 sha256=71ac618f4760be868c432fc819881d855f8dcb2d04148e011900b9c658fe6d9b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8f26o4iq/wheels/02/90/ef/7fa7ebaecbfec977f365d78fc8841efcb41aef6235ef8360d4
#   Building wheel for mendeleev (setup.py) ... done
#   Created wheel for mendeleev: filename=mendeleev-0.6.1-py2.py3-none-any.whl size=174958 sha256=c5f3e251204c280b5b9de9acdaddc9258ad3de35e3a84278b10f20404d639a4e
#   Stored in directory: /root/.cache/pip/wheels/32/06/4b/94bf864cb6fb3997c191fa69baf12bbc97d388fc937186399f
# Successfully built atomai mendeleev
# Installing collected packages: wadler-lindig, pyfiglet, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxtyping, nvidia-cusolver-cu12, linear-operator, mendeleev, gpytorch, atomai
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.10.19
#     Uninstalling nvidia-curand-cu12-10.3.10.19:
#       Successfully uninstalled nvidia-curand-cu12-10.3.10.19
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.4.0.6
#     Uninstalling nvidia-cufft-cu12-11.4.0.6:
#       Successfully uninstalled nvidia-cufft-cu12-11.4.0.6
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.9.0.13
#     Uninstalling nvidia-cublas-cu12-12.9.0.13:
#       Successfully uninstalled nvidia-cublas-cu12-12.9.0.13
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.9.5
#     Uninstalling nvidia-cusparse-cu12-12.5.9.5:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.9.5
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.4.40
#     Uninstalling nvidia-cusolver-cu12-11.7.4.40:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.4.40
# Successfully installed atomai-0.7.8.1.1 gpytorch-1.14 jaxtyping-0.3.2 linear-operator-0.6 mendeleev-0.6.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pyfiglet-1.0.2 wadler-lindig-0.1.6

# %%
# import all necessay libraries.
import pickle as pkl
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

import atomai as aoi
from atomai.utils import create_lattice_mask, extract_patches_
from atomai.transforms import datatransform

# %% [markdown]
# Import the instance segmentation utilities required by running the following command:

# %%
from atomai.utils.instance_seg_utils import *

# %% [markdown]
# Download [AM_dataset.pkl](https://drive.google.com/file/d/1s2_9Mmha7q6CcM5LRTyE1EbpbEE4Er5k/view?usp=sharing) and place it in your colab files. DO NOT use gdown or wget, as the file size is large, and it will not download correctly.**
#
# **: This behavior is due to gdown and wget's integration with google colab, and not with the dataset

# %%
with open('/kaggle/input/am-dataset-pkl/AM_dataset.pkl', 'rb') as f:
    data = pkl.load(f)

# %% [markdown]
# Set the images and the masks.

# %%
images=data['images']

# %%
masks=data['masks']

# %% [markdown]
# The following code squeezes the channels of the various classes. Additionally, some images contain a scale bar. This scale bar is irrelevant to the task at hand, thus we replace the 'scale-bar' class by average background intensity.

# %%
images_=[]
labels_=[]
for im,msk in zip(images,masks):
    im_arr=np.array([im])
    msk_arr=np.array([msk])
    im_arr,msk_arr=squeeze_channels2(im_arr,msk_arr)
    im_,msk_=replace_class_and_average(im_arr[0],msk_arr[0])

    images_.append(im_)
    labels_.append(msk_)

images_=np.array(images_,dtype="object")
labels_=np.array(labels_,dtype="object")

# %% [markdown]
# We shall split off the test data, then create patches of the rest of the image, label pairs and perform data augmentation.

# %%
images_train, images_test, masks_train, masks_test = get_train_test(images_,labels_)

# %%
def patch_base(images,labels):


    images_full, labels_full = extract_patches_(images[0], labels[0], patch_size=256, num_patches=500, random_state=42)

    for i in range(1,len(images)):
        images_all, labels_all = extract_patches_(images[i], labels[i], patch_size=256, num_patches=500, random_state=42)
        images_full=np.concatenate((images_full,images_all))
        labels_full=np.concatenate((labels_full,labels_all))
    return images_full,labels_full

# %%
images_all,labels_all=patch_base(images_train,masks_train)

# %%
ch = 4

# %%
# Define image distortion/noise parameters
zoom = 1.1 # zoom factor
poisson = [30, 40] # P noise range (scaled units)
gauss = [20, 100] # G noise range (scaled units)
blur = [1, 40] # Blurring range (scaled units)
contrast = [5, 14] # contrast range (< 10 is brighter, > 10 is darker)
salt_and_pepper = [1, 10] # min/max amount of salted/peppered pixels (scaled units)
# Run the augmentor
imaug = datatransform(
    n_channels=ch, dim_order_in='channel_last', dim_order_out='channel_first',
    gauss_noise=gauss, poisson_noise=poisson, salt_and_pepper=salt_and_pepper,
    contrast=contrast, blur=blur, zoom=zoom, rotation=True,
    squeeze_channels=False, seed=42)
images_all, labels_all = imaug.run(images_all, labels_all)

print(images_all.shape, labels_all.shape)
# Out:
# (4500, 1, 256, 256) (4500, 256, 256)

# %% [markdown]
# For the instance segmentation model, we need only two classes porosity and background. Thus we map both gas-induced:1 and lack of fusion:2 to porosity:1.

# %%
images_all2=[]
labels_all2=[]
for im,msk in zip(images_all,labels_all):
    im_arr=np.array([im])
    msk_arr=np.array([msk])

    msk_arr[0][msk_arr[0]==2]=1

    images_all2.append(im_arr[0])
    labels_all2.append(msk_arr[0])

# %%
images_all=np.array(images_all2)
labels_all=np.array(labels_all2)

# %%
images, images_val, labels, labels_val = train_test_split(
    images_all, labels_all, test_size=0.2, random_state=42)

# %% [markdown]
# We create the Tmapping of gas-induced:1 and lack of fusion:2 to porosity:1. Hwoever, for test we will save the actual labels for the test data  as well, and will use it to verify the performance of the final model

# %%
images_test_all2=[]
labels_test_all2=[]
labels_test_3class=[]


for im,msk in zip(images_test,masks_test ):
    im_arr=np.array([im])
    msk_arr=np.array([msk])

    labels_test_3class.append(msk_arr[0].copy())
    msk_arr[0][msk_arr[0]==2]=1
    images_test_all2.append(im_arr[0])
    labels_test_all2.append(msk_arr[0])

images_test=np.array(images_test_all2,dtype='object')
labels_test=np.array(labels_test_all2,dtype='object')
labels_test_3class=np.array(labels_test_3class,dtype='object')

# %%
np.unique(labels_test_3class[0])#actual labels
# Out:
# array([0., 1., 2.])

# %%
np.unique(labels[0])
# Out:
# array([0., 1.])

# %% [markdown]
# Let's plot some of the training data:

# %%
n = 5
k=1
n = n + 1
fig = plt.figure( figsize=(30, 8))
for i in range(1, n):
    ax = fig.add_subplot(2, n, i)
    ax.imshow(images[i-1+k,0,:,:], cmap='gray')
    ax.set_title('Augmented image ' + str(i-1) )
    ax.grid(alpha = 0.5)
    ax = fig.add_subplot(2, n, i+n)
    if labels.shape[1] == 1:
        ax.imshow(labels[i-1+k, 0], cmap='gray', interpolation='Gaussian')
    else:
        ax.imshow(labels[i-1+k], interpolation='Gaussian')
    ax.set_title('Ground truth ' + str(i-1))
    ax.grid(alpha=0.75)

# %% [markdown]
# Initialize a nodel for semantic segmentation. Note that the number of classes is 1. We will perform sematic segmentation and then transform the semantic maps to instance segmentation maps using the watershed algorithm

# %%
model = aoi.models.Segmentor(nb_classes=1)

# %%
print(model.net)
# Out:
# Unet(
#   (c1): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (c2): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (c3): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (bn): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): LeakyReLU(negative_slope=0.01)
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (upsample_block1): UpsampleBlock(
#     (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (c4): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (upsample_block2): UpsampleBlock(
#     (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (c5): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (upsample_block3): UpsampleBlock(
#     (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (c6): ConvBlock(
#     (block): Sequential(
#       (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (px): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 
# Epoch 313/5000 ... Training loss: 0.001826 ... Test loss: 0.002295 ... Train Accuracy: 0.931952 ... Test Accuracy: 0.909667 ... GPU memory usage: 4645/15360
# Epoch 314/5000 ... Training loss: 0.001816 ... Test loss: 0.002305 ... Train Accuracy: 0.932994 ... Test Accuracy: 0.909651 ... GPU memory usage: 4645/15360
# Epoch 315/5000 ... Training loss: 0.001817 ... Test loss: 0.002305 ... Train Accuracy: 0.932501 ... Test Accuracy: 0.910595 ... GPU memory usage: 4645/15360
# Epoch 316/5000 ... Training loss: 0.001802 ... Test loss: 0.002308 ... Train Accuracy: 0.934149 ... Test Accuracy: 0.90989 ... GPU memory usage: 4645/15360
# Epoch 317/5000 ... Training loss: 0.001829 ... Test loss: 0.002315 ... Train Accuracy: 0.931873 ... Test Accuracy: 0.909685 ... GPU memory usage: 4645/15360
# Epoch 318/5000 ... Training loss: 0.001825 ... Test loss: 0.002295 ... Train Accuracy: 0.932264 ... Test Accuracy: 0.910261 ... GPU memory usage: 4645/15360
# Epoch 319/5000 ... Training loss: 0.00181 ... Test loss: 0.002281 ... Train Accuracy: 0.93351 ... Test Accuracy: 0.910464 ... GPU memory usage: 4645/15360
# Epoch 320/5000 ... Training loss: 0.001804 ... Test loss: 0.002293 ... Train Accuracy: 0.933013 ... Test Accuracy: 0.910716 ... GPU memory usage: 4645/15360
# Epoch 321/5000 ... Training loss: 0.001801 ... Test loss: 0.002294 ... Train Accuracy: 0.933941 ... Test Accuracy: 0.910335 ... GPU memory usage: 4645/15360
# EARLY STOPPING @ step:  321
# Reverting to step:  220
# Plotting training history
# Calculating Automatic Threshold
# Batch 900/900
# 900 images were decoded in approximately 5.8522 seconds
# Checking Threshold item#:  19 / 19

# %% [markdown]
# # save model

# %%
import torch
# Save the model - CORRECT METHOD
torch.save(model.net.state_dict(), "instance_segmentor_weights.pth")

# %% [markdown]
# # load model

# %%
from atomai.models import Segmentor
import torch

# First create a new segmentor with same architecture
loaded_model = Segmentor(nb_classes=1)

# Then load the weights
loaded_model.net.load_state_dict(torch.load("atomai_segmentor_weights.pth"))

# %%
preds_probs=[]
preds=[]

for im in images_test:
    pred_m=model.predict(im)[0][0]
    print(pred_m.shape)

    preds_probs.append(pred_m)
    preds.append(convert_preds_to_classes(pred_m))
# Out:
# Performing auto-thresh prediction
# Batch 1/1
# 1 image was decoded in approximately 0.3089 seconds
# (1536, 2048, 1)
# Performing auto-thresh prediction
# Batch 1/1
# 1 image was decoded in approximately 0.2678 seconds
# (1536, 2048, 1)
# Performing auto-thresh prediction
# Batch 1/1
# 1 image was decoded in approximately 0.0325 seconds
# (480, 640, 1)

# %% [markdown]
# We use the following function that provides watershed markers, geometrical properties and polygons based on the prediction probabilities of the semantic segmentation module.
#
#
#
#
#   Returns:
#
#       - final_preds (list): List of NumPy arrays, each representing the final watershed markers for an image.
#       - properties (list): List of Pandas DataFrames, each containing geometric properties for regions in an image.
#       - polygons (list): List of NumPy arrays, each representing the approximated polygons for regions in an image.

# %%
final_preds, properties, polygons = pred_to_prop_masks(images_test,one_vs_all_preds(preds, class_id=1))

# %%
properties[0]#look at the geometric properties visible as a DataFrame
# Out:
#       area  perimeter  equivalent_diameter  major_axis_length  \
# 1     28.0  19.656854             5.970821           9.105862
# 2     12.0  12.207107             3.908820           8.301394
# 3    138.0  41.798990            13.255454          13.775674
# 4      1.0   0.000000             1.128379           0.000000
# 5     29.0  17.899495             6.076508           7.427086
# ..     ...        ...                  ...                ...
# 106    5.0   5.207107             2.523133           3.098387
# 107    6.0   6.000000             2.763953           3.265986
# 108   29.0  26.863961             6.076508          20.236791
# 109    1.0   0.000000             1.128379           0.000000
# 110   67.0  49.798990             9.236182          28.030350
#
#      minor_axis_length  eccentricity  orientation  solidity
# 1             4.133193      0.891050     0.315674  0.933333
# 2             1.937399      0.972385     1.398596  0.750000
# 3            12.768378      0.375361     1.542879  0.945205
# 4             0.000000      0.000000    -0.785398  1.000000
# 5             5.004764      0.738865    -0.824608  0.966667
# ..                 ...           ...          ...       ...
# 106           1.788854      0.816497    -1.249046  1.000000
# 107           2.000000      0.790569     1.570796  1.000000
# 108           1.980638      0.995199     1.148595  0.617021
# 109           0.000000      0.000000    -0.785398  1.000000
# 110           4.659737      0.986085     1.064562  0.620370
#
# [110 rows x 8 columns]

# %% [markdown]
# We shall now implemenet the following rule based on geometrical proerties:
#
# if $f(a, s) \leq 0.042$ and $f(d, a) \leq 0.491$ then the porosity is lack-of-fusion otherwise its gas induced.
#
#  Here, $a$, $s$ and $d$ represent the major axis length, solidity and the equivalent diameter of the instance, respectively. Further, function $f$ represent the transformation $f(x,y) = \frac{xy}{x^2+y^2}$.

# %%
df_fin_list=[]
delta_small=1e-10
for df in properties:
    data=df.copy()
    data['f(major_axis_length,solidity)']=(data['major_axis_length']*data['solidity'] / (data['major_axis_length']**2 + data['solidity']**2+delta_small))
    data['f(equivalent_diameter,major_axis_length)']=(data['equivalent_diameter']*data['major_axis_length'] / (data['equivalent_diameter']**2 + data['major_axis_length']**2+delta_small))
    data['class']=((data['f(major_axis_length,solidity)']<= 0.04144560918211937) & (data['f(equivalent_diameter,major_axis_length)']<= 0.49079978466033936)).astype(int)
    df_fin_list.append(data)

# %%
df_fin= pd.concat(df_fin_list, axis=0)#concat the Dataframes for visualization

# %% [markdown]
# We can now visualize the scatterplot of the instantiated porosities in the space of the geometric properties and view its distribution.

# %%
# Get the top 2 correlated columns (assuming you have correlations pre-computed)
top_cols = ['f(major_axis_length,solidity)','f(equivalent_diameter,major_axis_length)']  # Assuming columns at index 1 and 2 are most correlated

# Scatter plot with different markers for target classes
plt.figure(figsize=(8, 6))

class_data = df_fin[df_fin['class'] == 0]
plt.scatter(class_data[top_cols[0]], class_data[top_cols[1]],marker='o',facecolors='none', edgecolors='r', label='Gas-induced')

class_data = df_fin[df_fin['class'] == 1]
plt.scatter(class_data[top_cols[0]], class_data[top_cols[1]],marker='d',facecolors='none', edgecolors='b', label='Lack-of-Fusion')

plt.hlines(0.49079978466033936,xmin=0, xmax=max(df_fin[top_cols[0]]),linestyles='dashed', color='black', zorder=2)
plt.vlines(0.04144560918211937,ymin=0, ymax=max(df_fin[top_cols[1]]+0.015),linestyles='dashed', color='black', zorder=2)
plt.axis(xmin=-0.002,xmax=0.402)

plt.grid(True)

plt.xlabel(top_cols[0])
plt.ylabel(top_cols[1])
plt.title('2 Class model +Instance Seg + Rules: Scatter Plot by Target Class')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# Let us now look at the classification report:
#
#
# *   Precision
# *   Recall
# *   f1-score

# %%
masksf=[]
for i in range(3):
    h,w=final_preds[i].shape
    pl1,pl2=seperate_polygons(polygons[i],df_fin_list[i])
    mask=create_masks_from_polygon_sets(h,w,pl1,pl2)
    masksf.append(squeeze_channels_(mask))

# %%
labels_flat=np.array(flatten_array(labels_test_3class))

# %%
predsf=[ms[0] for ms in masksf]

# %%
predsf_flat=np.array(flatten_array(masksf))

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(labels_flat,predsf_flat,
                            target_names=['background','gas-induced','lack-of-fusion']))
# Out:
#                 precision    recall  f1-score   support
#
#     background       1.00      1.00      1.00   6591754
#    gas-induced       0.51      0.86      0.64      3383
# lack-of-fusion       0.82      0.75      0.79      3519
#
#       accuracy                           1.00   6598656
#      macro avg       0.78      0.87      0.81   6598656
#   weighted avg       1.00      1.00      1.00   6598656

# %% [markdown]
# We shall now overlay the predictions and compare with the ground truth.

# %%
rows=3
cols=2
# Create figure and axes grid
fig, axes = plt.subplots(rows, cols, figsize=(20, 15))
k=0
# Iterate through the plots
for i in range(3):

    ax = axes[i,0]  # Access the subpl
    ax.axis('off')

    ax.text(0,-0.03, f"Predicted Porosity %:{porosity(predsf[i+k],mode=0):.3f}", size=8, ha="left",
         transform=ax.transAxes)
    ax.text(0.5,-0.03, f"Predicted Gas-Induced %:{porosity(predsf[i+k],mode=1):.3f}", size=8, ha="center",
         transform=ax.transAxes)
    ax.text(1,-0.03, f"Predicted LoF %:{porosity(predsf[i+k],mode=2):.3f}", size=8, ha="right",
         transform=ax.transAxes)
    ax.text(0.5,-0.06, "                                         ", size=20, ha="center",
         transform=ax.transAxes)
    ax.imshow(images_test[i+k],cmap='gray')
    ax=get_im(predsf[i+k],title=f"2-class Model + Instance Segmentation Predictions: Image  #{i+k+1}",ax=ax)




    ax = axes[i,1]  # Access the subpl
    ax.axis('off')
    ax.text(0,-0.03, f"Actual Porosity %:{porosity(labels_test_3class[i+k],mode=0):.3f}", size=8, ha="left",
     transform=ax.transAxes)
    ax.text(0.5,-0.03, f"Actual Gas-Induced %:{porosity(labels_test_3class[i+k],mode=1):.3f}", size=8, ha="center",
         transform=ax.transAxes)
    ax.text(1,-0.03, f"Actual LoF %:{porosity(labels_test_3class[i+k],mode=2):.3f}", size=8, ha="right",
         transform=ax.transAxes)
    ax.text(0.5,-0.06, "                                         ", size=20, ha="center",
         transform=ax.transAxes)
    ax.imshow(images_test[i+k],cmap='gray')
    ax=get_im(labels_test_3class[i+k],title=f"Ground Truth : Image  #{i+k+1}",ax=ax)


# Adjust spacing and show the plots
fig.tight_layout()
plt.show()
